# %%
# Thêm thư viện
from PIL import Image
from imgtools import *

# %%
# Tạo đường dẫn lưu ảnh
directory = 'D:/MonHoc/ThiGiacMayTinh/File/Image'

# %%
# Đọc ảnh
my_path = 'D:/MonHoc/ThiGiacMayTinh/File/Image/p01.png'
img = load_image(my_path)

# %%
# Hiển thị ảnh
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=479x438>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=479x438>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=479x438>

# %%
# Transpose ảnh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=438x479>

# %%
# Transpose ảnh
transposed_image = transposed_image.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=479x438>
