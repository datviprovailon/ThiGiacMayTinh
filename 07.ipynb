# %%
# Cài đặt thư viện matplotlib
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Tạo đường dẫn lưu ảnh
directory = 'D:/MonHoc/ThiGiacMayTinh/File/Image'
# Đọc ảnh
my_path = 'D:/MonHoc/ThiGiacMayTinh/File/Image/p03.png'
img = Image.open(my_path)
# Hiển thị ảnh
plt.imshow(img)
print(img.size)
# Out:
# (1077, 258)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show() # Hiển thị

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
# Vẽ trên hình ảnh
x = [0, 200, 400, 600, 800, 1000]
y = [258, 200, 50, 120, 150, 258]
plt.imshow(img) # Hiển thị hình ảnh
plt.plot(x,y, 'ro-')
plt.show()
