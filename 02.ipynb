# %%
# Cài đặt Pillow
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in d:\monhoc\thigiacmaytinh\application\anaconda3\lib\site-packages (10.4.0)

# %%
# Thêm thư viện
from PIL import Image
from imgtools import *

# %%
import os

# %%
# Thư mục hiện tại
print(os.getcwd())
# Thư mục chứa ảnh
directory = 'D:/MonHoc/ThiGiacMayTinh/File/Image'
# Out:
# C:\Users\trand\Desktop\BaiTap

# %%
imgs = get_image_list(directory)

# %%
# Hiển thị toàn bộ ảnh
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (479, 438)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=479x438>
# (479, 438)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=479x438>
# (659, 331)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=659x331>
# (1077, 258)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1077x258>
# (958, 423)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=958x423>
# (658, 162)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=658x162>
