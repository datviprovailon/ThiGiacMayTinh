# %%
# Thêm thư viện
from PIL import Image
from imgtools import *

# %%
# Tạo đường dẫn lưu ảnh
directory = 'D:/MonHoc/ThiGiacMayTinh/File/Image'

# %%
# Đọc ảnh
my_path = 'D:/MonHoc/ThiGiacMayTinh/File/Image/p01.png'
img = load_image(my_path)

# %%
# Hiển thị ảnh
display(img)
print(img.size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=479x438>
# (479, 438)

# %%
# Định vị khu vực cắt
region = (0, 0, 250, 438)
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x438>

# %%
# Dán và xác định vị trí dán
paste_positon = (250, 0)
img.paste(cropped_image, paste_positon)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=479x438>
